# %%
import pandas as pd

# %%
file_path = "C:/Users/Home/Cincy-Reds-Boot-Camp/Data/2023-nwbc-reds.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    post_bat_score  post_fld_score  if_fielding_alignment  \
# 0               2              15               Standard
# ...

# %%
df.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'pitcher_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
df['total_score'] = df['home_score'] + df['away_score']

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    post_fld_score  if_fielding_alignment  of_fielding_alignment  spin_axis  \
# ...

# %%
df['description'].unique()
# Out:
# array(['hit_into_play', 'ball', 'called_strike', 'swinging_strike',
#        'foul', 'blocked_ball', 'swinging_strike_blocked', 'hit_by_pitch',
#        'foul_tip', 'foul_bunt', 'missed_bunt', 'bunt_foul_tip',
#        'pitchout'], dtype=object)

# %%
strike_events = ['called_strike', 'swinging_strike','foul',
                 'swinging_strike_blocked','foul_tip', 'foul_bunt',
                 'missed_bunt', 'bunt_foul_tip']

# %%
df.loc[df['description'].isin(strike_events)]
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 3             FF  2022-10-05           93.8           2.32           5.48
# 4             FF  2022-10-05           94.1           2.34           5.54
# 6             FF  2022-10-05           94.5           2.25           5.47
# 9             SI  2022-10-05           93.4           2.36           5.41
# 12            FF  2022-10-05           92.7           2.45           5.40
# ...          ...         ...            ...            ...            ...
# 49033        NaN  2022-03-31            NaN            NaN            NaN
# 49034        NaN  2022-03-31            NaN            NaN            NaN
# 49035        NaN  2022-03-31            NaN            NaN            NaN
# 49036        NaN  2022-03-31            NaN            NaN            NaN
# 49037        NaN  2022-03-31            NaN            NaN            NaN
#
#           pitcher_name  batter  pitcher     events      description  ...  \
# ...

# %%
df['is_strike'] = 0
df.loc[df['description'].isin(strike_events), 'is_strike'] = 1

# %%
df.head(50)
# Out:
#    pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0          FF  2022-10-05           93.8           2.39           5.44
# 1          FF  2022-10-05           93.3           2.30           5.51
# 2          SL  2022-10-05           84.3           2.45           5.21
# 3          FF  2022-10-05           93.8           2.32           5.48
# 4          FF  2022-10-05           94.1           2.34           5.54
# 5          FF  2022-10-05           93.8           2.33           5.50
# 6          FF  2022-10-05           94.5           2.25           5.47
# 7          FF  2022-10-05           92.8           2.48           5.40
# 8          FF  2022-10-05           94.7           2.32           5.55
# 9          SI  2022-10-05           93.4           2.36           5.41
# 10         FF  2022-10-05           94.0           2.34           5.47
# 11         FF  2022-10-05           93.5           2.28           5.52
# ...

# %% [markdown]
# Homework

# %%
# Create a new column 'is_2_strikes' and assign the boolean result of the comparison 'strikes == 2' to it
df['is_2_strikes'] = 0
df.loc[df['strikes']==2, 'is_2_strikes'] = 1
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    of_fielding_alignment  spin_axis  delta_home_win_exp  delta_run_exp  \
# ...

# %%
# Create a new column 'is_high_velo' and assign the boolean result of the comparison 'release_speed > 94' to it
df['is_high_velo'] = 0
df.loc[df['release_speed']>94, 'is_high_velo'] = 1
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    spin_axis  delta_home_win_exp  delta_run_exp  attack_zone  swing  \
# ...

# %%
# Create a function to check the conditions for the new column


def is_strike_in_heart(row):
    description = row['description']
    attack_zone = row['attack_zone']
    
 #   Check if the pitch is a called or swinging strike, not a foul
    if description in ['called_strike', 'swinging_strike'] and attack_zone == 'heart':
        return True
    else:
        return False

# Apply the function to create a new column 'is_strike_heart'
df['is_strike_heart'] = df.apply(is_strike_in_heart, axis=1)

df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    delta_home_win_exp  delta_run_exp  attack_zone  swing     batter_name  \
# ...

# %%
# Correct answer to Question above

csw = ['called_strike', 'swinging_strike']

df['strike_heart'] = 0
df.loc[(df['description'].isin(csw)) & (df['attack_zone']=='heart'), 'strike_heart']
# Out:
# 3        0
# 4        0
# 12       0
# 14       0
# 19       0
#         ..
# 48536    0
# 48543    0
# 48552    0
# 48578    0
# 48619    0
# Name: strike_heart, Length: 4535, dtype: int64

# %% [markdown]
# Day #2

# %%
df['is_reds_pitcher'] = 0

# %%
df.loc[(df['home_team']=='CIN') & (df['inning_topbot']=='Top')].shape
# Out:
# (13065, 102)

# %%
(df
 .loc[((df['home_team']=='CIN') &
       (df['inning_topbot']=='Top')) |
      ((df['away_team']=='CIN') &
       (df['inning_topbot']=='Bot')),
      'is_reds_pitcher']) = 1

# %%
df.head(50)
# Out:
#    pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0          FF  2022-10-05           93.8           2.39           5.44
# 1          FF  2022-10-05           93.3           2.30           5.51
# 2          SL  2022-10-05           84.3           2.45           5.21
# 3          FF  2022-10-05           93.8           2.32           5.48
# 4          FF  2022-10-05           94.1           2.34           5.54
# 5          FF  2022-10-05           93.8           2.33           5.50
# 6          FF  2022-10-05           94.5           2.25           5.47
# 7          FF  2022-10-05           92.8           2.48           5.40
# 8          FF  2022-10-05           94.7           2.32           5.55
# 9          SI  2022-10-05           93.4           2.36           5.41
# 10         FF  2022-10-05           94.0           2.34           5.47
# 11         FF  2022-10-05           93.5           2.28           5.52
# ...

# %%
df.loc[df['is_reds_pitcher']==1, ['pitcher_name', 'pitch_name', 'is_strike']].groupby(['pitcher_name', 'pitch_name'], as_index=False).mean()
# Out:
#         pitcher_name       pitch_name  is_strike
# 0    Anderson, Chase  4-Seam Fastball   0.437500
# 1    Anderson, Chase         Changeup   0.542857
# 2    Anderson, Chase        Curveball   0.368421
# 3    Anderson, Chase           Cutter   0.471910
# 4    Anderson, Chase           Sinker   0.464286
# ..               ...              ...        ...
# 141      Zeuch, T.J.           Slider   0.373134
# 142     Zimmer, Kyle  4-Seam Fastball   0.400000
# 143     Zimmer, Kyle         Changeup   1.000000
# 144     Zimmer, Kyle        Curveball   1.000000
# 145     Zimmer, Kyle           Slider   1.000000
#
# [146 rows x 3 columns]

# %%
df1 = df.loc[df['is_reds_pitcher']==1, ['pitcher_name', 'pitch_name', 'is_strike']].groupby(['pitcher_name', 'pitch_name'], as_index=False).mean()
df1 = df1.rename(columns={'is_strike':'avg'})
df1.head()
# Out:
#       pitcher_name       pitch_name       avg
# 0  Anderson, Chase  4-Seam Fastball  0.437500
# 1  Anderson, Chase         Changeup  0.542857
# 2  Anderson, Chase        Curveball  0.368421
# 3  Anderson, Chase           Cutter  0.471910
# 4  Anderson, Chase           Sinker  0.464286

# %% [markdown]
# Day #3

# %%
df2 = df.loc[df['is_reds_pitcher']==1, ['pitcher_name', 'pitch_name', 'is_strike']].groupby(['pitcher_name', 'pitch_name'], as_index=False).count()
df2 = df2.rename(columns={'is_strike':'count'})
df2.head()
# Out:
#       pitcher_name       pitch_name  count
# 0  Anderson, Chase  4-Seam Fastball    128
# 1  Anderson, Chase         Changeup    140
# 2  Anderson, Chase        Curveball     38
# 3  Anderson, Chase           Cutter     89
# 4  Anderson, Chase           Sinker     56

# %%
df3 = df1.merge(df2, on=['pitcher_name', 'pitch_name'])
df3.head()
# Out:
#       pitcher_name       pitch_name       avg  count
# 0  Anderson, Chase  4-Seam Fastball  0.437500    128
# 1  Anderson, Chase         Changeup  0.542857    140
# 2  Anderson, Chase        Curveball  0.368421     38
# 3  Anderson, Chase           Cutter  0.471910     89
# 4  Anderson, Chase           Sinker  0.464286     56

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pitcher_name = 'Greene, Hunter'
df_plt = df3.loc[df3['pitcher_name']==pitcher_name]
sns.barplot(data=df_plt, x='avg', y='pitch_name')
plt.show()
pitcher_name = 'Lodolo, Nick'
df_plt = df3.loc[df3['pitcher_name']==pitcher_name]
sns.barplot(data=df_plt, x='avg', y='pitch_name')
plt.show()
pitcher_name = 'Ashcraft, Graham'
df_plt = df3.loc[df3['pitcher_name']==pitcher_name]
sns.barplot(data=df_plt, x='avg', y='pitch_name')
plt.show()
pitcher_name = 'Gibaut, Ian'
df_plt = df3.loc[df3['pitcher_name']==pitcher_name]
sns.barplot(data=df_plt, x='avg', y='pitch_name')
plt.show()

# %%
pitchers = ['Greene, Hunter','Lodolo, Nick', 'Ashcraft, Graham','Gibaut, Ian']

for pitcher in pitchers:
    print(pitcher)
    df_plt = df3.loc[df3['pitcher_name']==pitcher]
    sns.barplot(data=df_plt, x='avg', y='pitch_name')
    plt.show()
# Out:
# Greene, Hunter
# Lodolo, Nick
# Ashcraft, Graham
# Gibaut, Ian

# %%
pitchers
# Out:
# ['Greene, Hunter', 'Lodolo, Nick', 'Ashcraft, Graham', 'Gibaut, Ian']

# %%
pitcher
# Out:
# 'Gibaut, Ian'

# %%
for pitcher in df3['pitcher_name'].unique():
    print(pitcher)
    df_plt = df3.loc[df3['pitcher_name']==pitcher]
    sns.barplot(data=df_plt, x='avg', y='pitch_name')
    plt.show()
# Out:
# Anderson, Chase
# Ashcraft, Graham
# Castillo, Luis
# Cessa, Luis
# Cruz, Fernando
# Detwiler, Ross
# Diehl, Phillip
# Dowdy, Kyle
# Duarte, Daniel
# Dugger, Robert
# Dunn, Justin
# Díaz, Alexis
# Espinal, Raynel
# Farmer, Buck
# Farrell, Luke
# Gibaut, Ian
# Greene, Hunter
# Gutierrez, Vladimir
# Hendrix, Ryan
# Hoffman, Jeff
# Kuhnel, Joel
# Law, Derek
# Lodolo, Nick
# Lopez, Alejo
# Mahle, Tyler
# Minor, Mike
# Moreta, Dauri
# Overton, Connor
# Reynolds, Matt
# Sanmartin, Reiver
# Santillan, Tony
# Schrock, Max
# Sims, Lucas
# Solomon, Jared
# Strickland, Hunter
# Warren, Art
# Wilson, Justin
# Zeuch, T.J.
# Zimmer, Kyle

# %% [markdown]
# Homework

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    attack_zone  swing     batter_name  total_score  is_strike is_2_strikes  \
# ...

# %%
# Question 1

# Rename 'attack_zone' to 'Attack Zones'
df = df.rename(columns={'attack_zone': 'Attack Zones'})

# Calculate the average amount of strikes in each 'Attack Zones'
avg_strikes = df.groupby('Attack Zones')['is_strike'].mean()

# Print the results
for zone, avg in avg_strikes.iteritems():
    print(f"The average amount of strikes thrown in the '{zone}' zone is {avg:.2f}")
# Out:
# The average amount of strikes thrown in the 'chase' zone is 0.20
# The average amount of strikes thrown in the 'heart' zone is 0.68
# The average amount of strikes thrown in the 'shadow' zone is 0.56
# The average amount of strikes thrown in the 'waste' zone is 0.14

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    Attack Zones  swing     batter_name  total_score  is_strike is_2_strikes  \
# ...

# %%
# Question 2

# Filter data for Reds pitchers and release_speed between 80 and 90
filtered_data = df[(df['is_reds_pitcher'] == 1) & (df['release_speed'] >= 80) & (df['release_speed'] <= 90)]

# Count the number of times each Reds pitcher throws into each 'Attack Zones'
pitch_counts = filtered_data.groupby(['pitcher_name', 'Attack Zones']).size().reset_index(name='pitch_count')

# Calculate the average strikes in each 'Attack Zones' for each Reds pitcher
avg_strikes = filtered_data.groupby(['pitcher_name', 'Attack Zones'])['is_strike'].mean().reset_index(name='avg_strikes')

# Merge the two DataFrames on 'pitcher_name' and 'Attack Zones'
merged_data = pd.merge(pitch_counts, avg_strikes, on=['pitcher_name', 'Attack Zones'])

# Print the merged DataFrame
print(merged_data)
# Out:
#          pitcher_name Attack Zones  pitch_count  avg_strikes
# 0     Anderson, Chase        chase           70     0.228571
# 1     Anderson, Chase        heart           42     0.809524
# 2     Anderson, Chase       shadow          113     0.584071
# 3     Anderson, Chase        waste           16     0.000000
# 4    Ashcraft, Graham        chase          128     0.328125
# ..                ...          ...          ...          ...
# 142       Zeuch, T.J.        heart           30     0.666667
# 143       Zeuch, T.J.       shadow           49     0.408163
# 144       Zeuch, T.J.        waste           15     0.000000
# 145      Zimmer, Kyle        chase            2     1.000000
# 146      Zimmer, Kyle       shadow            2     1.000000
#
# [147 rows x 4 columns]

# %%
# Question 3

# Step 1: For each batter, what pitch types did they hit for home runs?
batter_hr = df[df['events'] == 'home_run'].groupby('batter')['pitch_type'].unique().reset_index()
batter_hr.columns = ['batter', 'hr_pitch_types']

# Step 2: For each pitcher, what is their most frequently thrown pitch type?
def most_common_pitch(x):
    try:
        return x.value_counts().index[0]
    except IndexError:
        return None

pitcher_pitches = df.groupby('pitcher_name')['pitch_type'].apply(most_common_pitch).reset_index()
pitcher_pitches.columns = ['pitcher_name', 'most_frequent_pitch']


# Step 3: Join batters and pitchers together
# Since this is a many-to-many relationship, we will use a cross join
batter_hr['key'] = 1
pitcher_pitches['key'] = 1
merged = pd.merge(batter_hr, pitcher_pitches, on='key').drop('key', axis=1)

# Step 4: Check to see if the batter and the pitcher ever matched up against each other in this dataset
matchups = df[['pitcher_name', 'batter']].drop_duplicates()
matchups['matched'] = True
merged = pd.merge(merged, matchups, how='left', on=['pitcher_name', 'batter'])
merged['matched'].fillna(False, inplace=True)

# Print the DataFrame
print(merged)
# Out:
#        batter hr_pitch_types      pitcher_name most_frequent_pitch  matched
# 0      405395       [SL, FF]     Abreu, Albert                  SI    False
# 1      405395       [SL, FF]       Adam, Jason                  CH    False
# 2      405395       [SL, FF]     Adams, Austin                None    False
# 3      405395       [SL, FF]        Adon, Joan                  FF    False
# 4      405395       [SL, FF]  Alcantara, Sandy                  SI    False
# ...       ...            ...               ...                 ...      ...
# 59338  681082           [FF]      Wright, Kyle                  CU    False
# 59339  681082           [FF]    Yajure, Miguel                  CU    False
# 59340  681082           [FF]   Zabala, Aneurys                  FF    False
# 59341  681082           [FF]       Zeuch, T.J.                  SI     True
# 59342  681082           [FF]      Zimmer, Kyle                  FF    False
#
# [59343 rows x 5 columns]

# %%
# Question 4

# five random pitchers
pitchers = ['Greene, Hunter', 'Lodolo, Nick', 'Ashcraft, Graham', 'Gibaut, Ian'] 

# Filter the dataframe to include only the chosen pitchers
df_pitchers = df[df['pitcher_name'].isin(pitchers)]

# Create a bar plot
plt.figure(figsize=(12, 8))
ax = sns.countplot(data=df_pitchers, x='pitcher_name', hue='pitch_type', order=df_pitchers['pitcher_name'].value_counts().index, palette='viridis')

plt.title('Number of Each Pitch Type Thrown by Each Pitcher', fontsize=20)
plt.xlabel('Pitcher Name', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.grid(axis='y')

# Customize the legend
legend = ax.legend()
legend.set_title('Pitch Type')

plt.show()

# %%
# Question 5

# Scatterplot for the entire dataset
plt.figure(figsize=(10,6))
sns.scatterplot(data=df3, x='avg', y='count')
plt.title('Scatterplot of count vs avg for the entire dataset')
plt.xlabel('Average Strike Rate')
plt.ylabel('Pitch Count')
plt.show()

# %%
# Question 5

# Scatterplot for a subsample (For example, Hunter Greene)
df_greene = df3[df3['pitcher_name'] == 'Greene, Hunter']
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_greene, x='avg', y='count')
plt.title('Scatterplot of count vs avg for Hunter Greene')
plt.xlabel('Average Strike Rate')
plt.ylabel('Pitch Count')
plt.show()

# %%
# Question 6

# Find the best and worst pitch type for each pitcher
best_pitch = df3.loc[df3.groupby('pitcher_name')['avg'].idxmax()]
worst_pitch = df3.loc[df3.groupby('pitcher_name')['avg'].idxmin()]

# Rename the columns for better understanding
best_pitch = best_pitch.rename(columns={'pitch_name': 'best_pitch', 'avg': 'best_pitch_avg'})
worst_pitch = worst_pitch.rename(columns={'pitch_name': 'worst_pitch', 'avg': 'worst_pitch_avg'})

# Merging the best and worst pitch dataframes
pitcher_performance = pd.merge(best_pitch[['pitcher_name', 'best_pitch', 'best_pitch_avg']],
                               worst_pitch[['pitcher_name', 'worst_pitch', 'worst_pitch_avg']],
                               on='pitcher_name')

pitcher_performance.head()
# Out:
#        pitcher_name       best_pitch  best_pitch_avg      worst_pitch  \
# 0   Anderson, Chase         Changeup        0.542857           Slider
# 1  Ashcraft, Graham           Cutter        0.481481         Changeup
# 2    Castillo, Luis  4-Seam Fastball        0.543668         Changeup
# 3       Cessa, Luis           Sinker        0.466667  4-Seam Fastball
# 4    Cruz, Fernando           Sinker        0.600000  4-Seam Fastball
#
#    worst_pitch_avg
# 0         0.309524
# 1         0.333333
# 2         0.430894
# 3         0.397590
# 4         0.396825

# %%
# Question 7

# Copy the original dataframe
df_analysis = df.copy()

# Create a column for strikes
df_analysis['is_strike'] = df_analysis['type'].apply(lambda x: 1 if x == 'S' else 0)

# Create a column for balls
df_analysis['is_ball'] = df_analysis['type'].apply(lambda x: 1 if x == 'B' else 0)

# Create columns for different hit types
df_analysis['is_home_run'] = df_analysis['events'].apply(lambda x: 1 if x == 'home_run' else 0)
df_analysis['is_hit'] = df_analysis['events'].apply(lambda x: 1 if x in ['single', 'double', 'triple'] else 0)

# Create columns for handedness of hitters
df_analysis['is_left_handed'] = df_analysis['stand'].apply(lambda x: 1 if x == 'L' else 0)
df_analysis['is_right_handed'] = df_analysis['stand'].apply(lambda x: 1 if x == 'R' else 0)

# %%
# Subset the dataframe for 'Greene, Hunter'
df_greene = df_analysis[df_analysis['pitcher_name'] == 'Greene, Hunter']

# %%
# Calculate overall strike rate
strike_rate = df_greene['is_strike'].sum() / df_greene.shape[0]
print(f"Overall strike rate: {strike_rate:.2f}")
# Out:
# Overall strike rate: 0.49

# %%
# Calculate strike rate by pitch type and hitter handedness
pitch_type_strike_rate = df_greene.groupby('pitch_type')['is_strike'].mean()
handedness_strike_rate = df_greene.groupby(['is_left_handed', 'is_right_handed'])['is_strike'].mean()

# Print the strike rates
print("Strike Rate by Pitch Type:")
print(pitch_type_strike_rate)
print("\nStrike Rate by Hitter Handedness:")
print(handedness_strike_rate)
# Out:
# Strike Rate by Pitch Type:
# pitch_type
# CH    0.288136
# FF    0.521151
# SL    0.486667
# Name: is_strike, dtype: float64
#
# Strike Rate by Hitter Handedness:
# is_left_handed  is_right_handed
# 0               1                  0.487057
# 1               0                  0.498771
# Name: is_strike, dtype: float64

# %%
# Group data by game_date and calculate average strike rate
strike_rate_over_time = df_greene.groupby('game_date')['is_strike'].mean()

# Plot the strike rate trend
plt.figure(figsize=(10, 6))
strike_rate_over_time.plot(kind='line', marker='o')
plt.title("Strike Rate Trend Over Time")
plt.xlabel("Game Date")
plt.ylabel("Strike Rate")
plt.grid(True)
plt.show()

# %%
# Group data by count and calculate average strike rate
strike_rate_by_count = df_greene.groupby(['balls', 'strikes'])['is_strike'].mean().reset_index()

# Plot the strike rate by count
plt.figure(figsize=(10, 6))
plt.bar(strike_rate_by_count['balls'].astype(str) + "-" + strike_rate_by_count['strikes'].astype(str),
        strike_rate_by_count['is_strike'])
plt.title("Strike Rate by Count")
plt.xlabel("Count")
plt.ylabel("Strike Rate")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
